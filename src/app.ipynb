# %%
from data_pull import spotify_data
from prompt_gen import generate_prompt
from ai_optimizer import playlist_opt
import json
import streamlit as st

# %%
anzahl_neuer_songs = 10
grenze_gelöschter_songs = 5
playlist_vibe = "Latenight Drive"
playlist_id = "6TEtUXHUQkQAs2whkLzzlY"

# %%
tracks = spotify_data(playlist_id)

# %%
opt_prompt = generate_prompt(tracks, anzahl_neuer_songs, grenze_gelöschter_songs, playlist_vibe)
data = playlist_opt(opt_prompt)

# %%
clean = data.text.strip().removeprefix("```json").removesuffix("```").strip()
print(clean)
data = json.loads(clean)
# Out:
# {
#   "removed_songs": [
#     {
#       "idx": 0,
#       "artist": "Swedish House Mafia",
#       "track_name": "Moth To A Flame (with The Weeknd)"
#     },
#     {
#       "idx": 1,
#       "artist": "Artemas",
#       "track_name": "if u think i'm pretty"
#     },
#     {
#       "idx": 2,
#       "artist": "Artemas",
#       "track_name": "cross my heart"
#     },
#     {
#       "idx": 3,
#       "artist": "The Weeknd",
#       "track_name": "In The Night"
#     },
#     {
#       "idx": 4,
#       "artist": "Metro Boomin",
#       "track_name": "Borrowed Love (feat. Swae Lee & WizKid)"
#     }
#   ],
#   "added_songs": [
#     {
#       "idx": 0,
#       "artist": "The Weeknd",
#       "track_name": "Often"
#     },
#     {
#       "idx": 1,
#       "artist": "KAYTRANADA",
#       "track_name": "Lite Spots"
#     },
#     {
#       "idx": 2,
#       "artist": "Giveon",
#       "track_name": "Heartbreak Anniversary"
#     },
#     {
#       "idx": 3,
#       "artist": "Sonder",
#       "track_name": "Too Fast"
#     },
#     {
#       "idx": 4,
#       "artist": "Frank Ocean",
#       "track_name": "Nights"
#     },
#     {
#       "idx": 5,
#       "artist": "FKJ",
#       "track_name": "Ylang Ylang"
#     },
#     {
#       "idx": 6,
#       "artist": "Mac Miller",
#       "track_name": "Self Care"
#     },
#     {
#       "idx": 7,
#       "artist": "Daniel Caesar",
#       "track_name": "Get You (feat. Kali Uchis)"
#     },
#     {
#       "idx": 8,
#       "artist": "Drake",
#       "track_name": "Hotline Bling"
#     },
#     {
#       "idx": 9,
#       "artist": "Joji",
#       "track_name": "Glimpse of Us"
#     }
#   ],
#   "final_playlist": [
#     {
#       "idx": 0,
#       "artist": "Tory Lanez",
#       "track_name": "The Color Violet"
#     },
#     {
#       "idx": 1,
#       "artist": "Darci",
#       "track_name": "On My Own"
#     },
#     {
#       "idx": 2,
#       "artist": "Metro Boomin",
#       "track_name": "Creepin' (with The Weeknd & 21 Savage)"
#     },
#     {
#       "idx": 3,
#       "artist": "Tory Lanez",
#       "track_name": "Lavender Sunflower"
#     },
#     {
#       "idx": 4,
#       "artist": "The Weeknd",
#       "track_name": "Reminder"
#     },
#     {
#       "idx": 5,
#       "artist": "Metro Boomin",
#       "track_name": "Around Me (feat. Don Toliver)"
#     },
#     {
#       "idx": 6,
#       "artist": "EKKSTACY",
#       "track_name": "Uncomparable"
#     },
#     {
#       "idx": 7,
#       "artist": "Elle Eliades",
#       "track_name": "You"
#     },
#     {
#       "idx": 8,
#       "artist": "Metro Boomin",
#       "track_name": "Too Many Nights (feat. Don Toliver & with Future)"
#     },
#     {
#       "idx": 9,
#       "artist": "Travis Scott",
#       "track_name": "sdp interlude"
#     },
#     {
#       "idx": 10,
#       "artist": "Metro Boomin",
#       "track_name": "Trance (with Travis Scott & Young Thug)"
#     },
#     {
#       "idx": 11,
#       "artist": "The Weeknd",
#       "track_name": "I Was Never There"
#     },
#     {
#       "idx": 12,
#       "artist": "The Weeknd",
#       "track_name": "Is There Someone Else?"
#     },
#     {
#       "idx": 13,
#       "artist": "SZA",
#       "track_name": "Low"
#     },
#     {
#       "idx": 14,
#       "artist": "Brent Faiyaz",
#       "track_name": "ROLE MODEL"
#     },
#     {
#       "idx": 15,
#       "artist": "Brent Faiyaz",
#       "track_name": "Best Time"
#     },
#     {
#       "idx": 16,
#       "artist": "Tory Lanez",
#       "track_name": "Hurts Me"
#     },
#     {
#       "idx": 17,
#       "artist": "Post Malone",
#       "track_name": "Feel"
#     },
#     {
#       "idx": 18,
#       "artist": "Brent Faiyaz",
#       "track_name": "Trust"
#     },
#     {
#       "idx": 19,
#       "artist": "Jonah Zed",
#       "track_name": "low life in love"
#     },
#     {
#       "idx": 20,
#       "artist": "Don Toliver",
#       "track_name": "NEW DROP"
#     },
#     {
#       "idx": 21,
#       "artist": "Baby Keem",
#       "track_name": "16"
#     },
#     {
#       "idx": 22,
#       "artist": "Darci",
#       "track_name": "Wild Horse"
#     },
#     {
#       "idx": 23,
#       "artist": "The Neighbourhood",
#       "track_name": "Softcore"
#     },
#     {
#       "idx": 24,
#       "artist": "Darci",
#       "track_name": "Grave Shift"
#     },
#     {
#       "idx": 25,
#       "artist": "The Weeknd",
#       "track_name": "Party Monster"
#     },
#     {
#       "idx": 26,
#       "artist": "Don Toliver",
#       "track_name": "Private Landing (feat. Justin Bieber & Future)"
#     },
#     {
#       "idx": 27,
#       "artist": "Frank Ocean",
#       "track_name": "Pink + White"
#     },
#     {
#       "idx": 28,
#       "artist": "PARTYNEXTDOOR",
#       "track_name": "Break from Toronto"
#     },
#     {
#       "idx": 29,
#       "artist": "The Weeknd",
#       "track_name": "House Of Balloons / Glass Table Girls"
#     },
#     {
#       "idx": 30,
#       "artist": "Travis Scott",
#       "track_name": "I KNOW ?"
#     },
#     {
#       "idx": 31,
#       "artist": "The Weeknd",
#       "track_name": "Often"
#     },
#     {
#       "idx": 32,
#       "artist": "KAYTRANADA",
#       "track_name": "Lite Spots"
#     },
#     {
#       "idx": 33,
#       "artist": "Giveon",
#       "track_name": "Heartbreak Anniversary"
#     },
#     {
#       "idx": 34,
#       "artist": "Sonder",
#       "track_name": "Too Fast"
#     },
#     {
#       "idx": 35,
#       "artist": "Frank Ocean",
#       "track_name": "Nights"
#     },
#     {
#       "idx": 36,
#       "artist": "FKJ",
#       "track_name": "Ylang Ylang"
#     },
#     {
#       "idx": 37,
#       "artist": "Mac Miller",
#       "track_name": "Self Care"
#     },
#     {
#       "idx": 38,
#       "artist": "Daniel Caesar",
#       "track_name": "Get You (feat. Kali Uchis)"
#     },
#     {
#       "idx": 39,
#       "artist": "Drake",
#       "track_name": "Hotline Bling"
#     },
#     {
#       "idx": 40,
#       "artist": "Joji",
#       "track_name": "Glimpse of Us"
#     }
#   ]
# }

# %%
removed_songs = data["removed_songs"]
added_songs = data["added_songs"]
final_playlist = data["final_playlist"]

print(added_songs)
# Out:
# [{'idx': 0, 'artist': 'The Weeknd', 'track_name': 'Often'}, {'idx': 1, 'artist': 'KAYTRANADA', 'track_name': 'Lite Spots'}, {'idx': 2, 'artist': 'Giveon', 'track_name': 'Heartbreak Anniversary'}, {'idx': 3, 'artist': 'Sonder', 'track_name': 'Too Fast'}, {'idx': 4, 'artist': 'Frank Ocean', 'track_name': 'Nights'}, {'idx': 5, 'artist': 'FKJ', 'track_name': 'Ylang Ylang'}, {'idx': 6, 'artist': 'Mac Miller', 'track_name': 'Self Care'}, {'idx': 7, 'artist': 'Daniel Caesar', 'track_name': 'Get You (feat. Kali Uchis)'}, {'idx': 8, 'artist': 'Drake', 'track_name': 'Hotline Bling'}, {'idx': 9, 'artist': 'Joji', 'track_name': 'Glimpse of Us'}]
